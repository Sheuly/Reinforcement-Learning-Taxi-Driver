# %%
# !pip install cmake scipy pygame
# Out:
# Requirement already satisfied: cmake in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (3.28.1)
# Requirement already satisfied: scipy in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (1.11.4)
# Requirement already satisfied: pygame in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (2.5.2)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scipy) (1.26.1)

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (23.3.2)

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: scikit-learn in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 4)) (3.8.1)
# Requirement already satisfied: seaborn in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 5)) (0.13.0)
# Requirement already satisfied: jupyter in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: gymnasium in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 8)) (0.29.1)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 1)) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->-r requirements.txt (line 2)) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (4.44.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (3.1.1)
# Requirement already satisfied: notebook in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter->-r requirements.txt (line 6)) (7.0.5)
# Requirement already satisfied: qtconsole in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter->-r requirements.txt (line 6)) (5.4.4)
# Requirement already satisfied: jupyter-console in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter->-r requirements.txt (line 6)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter->-r requirements.txt (line 6)) (7.9.2)
# Requirement already satisfied: ipykernel in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter->-r requirements.txt (line 6)) (6.25.2)
# Requirement already satisfied: ipywidgets in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter->-r requirements.txt (line 6)) (8.1.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from gymnasium->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from gymnasium->-r requirements.txt (line 8)) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from gymnasium->-r requirements.txt (line 8)) (0.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (8.16.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (8.4.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (5.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (1.5.8)
# Requirement already satisfied: psutil in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (5.9.6)
# Requirement already satisfied: pyzmq>=20 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 6)) (5.11.2)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 6)) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-console->jupyter->-r requirements.txt (line 6)) (3.0.39)
# Requirement already satisfied: pygments in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-console->jupyter->-r requirements.txt (line 6)) (2.16.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter->-r requirements.txt (line 6)) (2.8.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter->-r requirements.txt (line 6)) (2.25.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter->-r requirements.txt (line 6)) (4.0.7)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter->-r requirements.txt (line 6)) (0.2.3)
# Requirement already satisfied: ipython-genutils in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from qtconsole->jupyter->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from qtconsole->jupyter->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: webencodings in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: backcall in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: decorator in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.19.1)
# Requirement already satisfied: pickleshare in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.6.3)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 6)) (3.11.0)
# Requirement already satisfied: pywin32>=300 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 6)) (306)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: argon2-cffi in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (0.4.4)
# Requirement already satisfied: overrides in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (0.17.1)
# Requirement already satisfied: pywinpty in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (2.0.12)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.6.4)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->-r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (2.13.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (4.19.1)
# Requirement already satisfied: requests>=2.31 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: fastjsonschema in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter->-r requirements.txt (line 6)) (2.18.1)
# Requirement already satisfied: wcwidth in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->-r requirements.txt (line 6)) (0.2.8)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 6)) (2.5)
# Requirement already satisfied: idna>=2.8 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (3.3.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 6)) (2023.7.22)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (2.4)
# Requirement already satisfied: uri-template in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 6)) (2.8.19.14)

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import random
from IPython.display import clear_output
from time import sleep
from matplotlib import animation

# %%
"""Initialize and validate the environment"""
env = gym.make("Taxi-v3", render_mode="rgb_array").env
state, _ = env.reset()

# Print dimensions of state and action space
print("State space: {}".format(env.observation_space))
print("Action space: {}".format(env.action_space))

# Sample random action
action = env.action_space.sample(env.action_mask(state))
next_state, reward, done, _, _ = env.step(action)

# Print output
print("State: {}".format(state))
print("Action: {}".format(action))
print("Action mask: {}".format(env.action_mask(state)))
print("Reward: {}".format(reward))

# Render and plot an environment frame
frame = env.render()
plt.imshow(frame)
plt.axis("off")
plt.show()
# Out:
# State space: Discrete(500)
# Action space: Discrete(6)
# State: 62
# Action: 2
# Action mask: [1 0 1 1 0 0]
# Reward: -1
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.action_mask to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.action_mask` for environment variables or `env.get_wrapper_attr('action_mask')` that will search the reminding wrappers.
#   logger.warn(

# %%
def run_animation(experience_buffer):
    """Function to run animation"""
    time_lag = 0.05  # Delay (in s) between frames
    for experience in experience_buffer:
        # Plot frame
        clear_output(wait=True)
        plt.imshow(experience['frame'])
        plt.axis('off')
        plt.show()

        # Print console output
        print(f"Episode: {experience['episode']}/{experience_buffer[-1]['episode']}")
        print(f"Epoch: {experience['epoch']}/{experience_buffer[-1]['epoch']}")
        print(f"State: {experience['state']}")
        print(f"Action: {experience['action']}")
        print(f"Reward: {experience['reward']}")
        # Pauze animation
        sleep(time_lag)

# %%
def store_episode_as_gif(experience_buffer, path='./', filename='animation.gif'):
    """Store episode as gif animation"""
    fps = 5   # Set framew per seconds
    dpi = 300  # Set dots per inch
    interval = 50  # Interval between frames (in ms)

    # Retrieve frames from experience buffer
    frames = []
    for experience in experience_buffer:
        frames.append(experience['frame'])

    # Fix frame size
    plt.figure(figsize=(frames[0].shape[1] / dpi, frames[0].shape[0] / dpi), dpi=dpi)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    # Generate animation
    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=interval)

    # Save output as gif
    anim.save(path + filename, writer='imagemagick', fps=fps)

# %% [markdown]
# ### Testing a random agent

# %%
"""Simulation with random agent"""
epoch = 0
num_failed_dropoffs = 0
experience_buffer = []
cum_reward = 0

done = False

state, _ = env.reset()

while not done:
    # Sample random action
    "Action selection without action mask"
    action = env.action_space.sample()

    "Action selection with action mask"
    #action = env.action_space.sample(env.action_mask(state))

    state, reward, done, _, _ = env.step(action)
    cum_reward += reward

    # Store experience in dictionary
    experience_buffer.append({
        "frame": env.render(),
        "episode": 1,
        "epoch": epoch,
        "state": state,
        "action": action,
        "reward": cum_reward,
        }
    )

    if reward == -10:
        num_failed_dropoffs += 1

    epoch += 1

# Run animation and print console output
run_animation(experience_buffer)

print("# epochs: {}".format(epoch))
print("# failed drop-offs: {}".format(num_failed_dropoffs))
# Out:
# Episode: 1/1
# Epoch: 5051/5051
# State: 475
# Action: 5
# Reward: -19683
# # epochs: 5052
# # failed drop-offs: 1628

# %% [markdown]
# ### Training the agent

# %%
"""Training the agent"""
q_table = np.zeros([env.observation_space.n, env.action_space.n])

# %%
# Hyperparameters
alpha = 0.1  # Learning rate
gamma = 1.0  # Discount rate
epsilon = 0.1  # Exploration rate
num_episodes = 10000  # Number of episodes

# Output for plots
cum_rewards = np.zeros([num_episodes])
total_epochs = np.zeros([num_episodes])

# %%
for episode in range(1, num_episodes+1):
    # Reset environment
    state, info = env.reset()
    epoch = 0 
    num_failed_dropoffs = 0
    done = False
    cum_reward = 0

    while not done:
        
        if random.uniform(0, 1) < epsilon:
            "Basic exploration [~0.47m]"
            action = env.action_space.sample() # Sample random action (exploration)
            
            "Exploration with action mask [~1.52m]"
          # action = env.action_space.sample(env.action_mask(state)) "Exploration with action mask"
        else:      
            "Exploitation with action mask [~1m52s]"
           # action_mask = np.where(info["action_mask"]==1,0,1) # invert
           # masked_q_values = np.ma.array(q_table[state], mask=action_mask, dtype=np.float32)
           # action = np.ma.argmax(masked_q_values, axis=0)

            "Exploitation with random tie breaker [~1m19s]"
          #  action = np.random.choice(np.flatnonzero(q_table[state] == q_table[state].max()))
            
            "Basic exploitation [~47s]"
            action = np.argmax(q_table[state]) # Select best known action (exploitation)
 
        next_state, reward, done, _ , info = env.step(action) 

        cum_reward += reward
        
        old_q_value = q_table[state, action]
        next_max = np.max(q_table[next_state])
        
        new_q_value = (1 - alpha) * old_q_value + alpha * (reward + gamma * next_max)
        
        q_table[state, action] = new_q_value
        
        if reward == -10:
            num_failed_dropoffs += 1

        state = next_state
        epoch += 1
        
        total_epochs[episode-1] = epoch
        cum_rewards[episode-1] = cum_reward

    if episode % 100 == 0:
        clear_output(wait=True)
        print(f"Episode #: {episode}")

print("\n")
print("===Training completed.===\n")
# Out:
# Episode #: 10000
#
#
# ===Training completed.===

# %%
# Plot reward convergence
plt.title("Cumulative reward per episode")
plt.xlabel("Episode")
plt.ylabel("Cumulative reward")
plt.plot(cum_rewards)
plt.show()

# Plot epoch convergence
plt.title("# epochs per episode")
plt.xlabel("Episode")
plt.ylabel("# epochs")
plt.plot(total_epochs)
plt.show()

# %% [markdown]
# ### Testing the policy

# %%
"""Test policy performance after training"""

num_epochs = 0
total_failed_deliveries = 0
num_episodes = 1
experience_buffer = []
store_gif = True

for episode in range(1, num_episodes+1):
    # Initialize experience buffer

    my_env = env.reset()
    state = my_env[0]
    epoch = 1 
    num_failed_deliveries =0
    cum_reward = 0
    done = False

    while not done:
        action = np.argmax(q_table[state])
        state, reward, done, _, _ = env.step(action)
        cum_reward += reward

        if reward == -10:
            num_failed_deliveries += 1

        # Store rendered frame in animation dictionary
        experience_buffer.append({
            'frame': env.render(),
            'episode': episode,
            'epoch': epoch,
            'state': state,
            'action': action,
            'reward': cum_reward
            }
        )

        epoch += 1

    total_failed_deliveries += num_failed_deliveries
    num_epochs += epoch

    if store_gif:
        store_episode_as_gif(experience_buffer)

# Run animation and print output
run_animation(experience_buffer)
# Out:
# Episode: 1/1
# Epoch: 12/12
# State: 410
# Action: 5
# Reward: 9

# %%
# Print final results
print("\n") 
print(f"Test results after {num_episodes} episodes:")
print(f"Mean # epochs per episode: {num_epochs / num_episodes}")
print(f"Mean # failed drop-offs per episode: {total_failed_deliveries / num_episodes}")
# Out:
# Test results after 1 episodes:
# Mean # epochs per episode: 13.0
# Mean # failed drop-offs per episode: 0.0
